# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !ls plaid_csvs/peer
# Out:
# beta_len256.csv    original_peer_stripped.csv	    subloc_len256.csv
# binloc_len256.csv  properties_benchmark_len256.csv  thermo_len256.csv
# fluo_len256.csv    soluability_len256.csv
# fold_len256.csv    stability_len256.csv

# %%
import pandas as pd
baselines = pd.read_csv("plaid_csvs/peer/original_peer_stripped.csv", sep=",")

# %%
baselines
# Out:
#    Unnamed: 0    DDE   Moran    LSTM  Transformer     CNN  ResNet  ProtBert  \
# 0         Flu  0.638   0.400   0.494        0.643   0.682   0.636     0.679
# 1         Sta  0.652   0.322   0.533        0.649   0.637   0.126     0.771
# 2       β-lac  0.623   0.375   0.139        0.261   0.781   0.152     0.731
# 3         Sol  59.77  57.730  70.180       70.120  64.430  67.330    68.150
# 4         Sub  49.17  31.130  62.980       56.020  58.730  52.300    76.530
# 5         Bin  77.43  55.630  88.110       75.740  82.670  78.990    91.320
# 6        Cont     --  26.340  17.500       10.000  20.430  39.660    24.350
# 7        Fold   9.57   7.100   8.240        8.520  10.930   8.890    16.940
# 8         SSP     --  68.990  59.620       66.070  69.560  82.180    62.510
# 9         Yst  55.83  53.000  53.620       54.120  55.070  48.910    63.720
# 10        Hum  62.77  54.670  63.750       59.580  62.600  68.610    77.320
# ...

# %% [markdown]
# # beta lactamase

# %%
runs_df = pd.read_csv("plaid_csvs/peer/properties_benchmark_len256.csv", sep=",") 
print(runs_df.shape)
print(runs_df['test_set.dataset.class'].unique())
runs_df.head()

# beta_df = runs_df["test_set.dataset.class"] =
# Out:
# (79, 103)
# ['datasets.Fluorescence' 'datasets.SubcellularLocalization'
#  'datasets.Thermostability' 'datasets.Stability'
#  'datasets.BinaryLocalization' 'datasets.BetaLactamase'
#  'datasets.Solubility' 'datasets.Fold']
#                 Name test_set.dataset.class task.model.compression_model_id  \
# 0   feasible-eon-227  datasets.Fluorescence                        8ebs7j9h
# 1     usual-moon-226  datasets.Fluorescence                        mm9fe6x9
# 2  whole-glitter-225  datasets.Fluorescence                        kyytc8i9
# 3     proud-bird-224  datasets.Fluorescence                        fbbrfqzk
# 4  light-morning-223  datasets.Fluorescence                        13lltqha
#
#       State  batch_size  Runtime Notes        User  Tags  \
# 0  finished          64    44638     -  lu-amy-al1   NaN
# 1    killed          64    20083     -  lu-amy-al1   NaN
# 2  finished          64    44487     -  lu-amy-al1   NaN
# 3  finished          64    44461     -  lu-amy-al1   NaN
# ...

# %%
beta_df = runs_df
